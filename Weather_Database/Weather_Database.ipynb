# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 733

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_name = city_weather["name"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]   
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City":city_name,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hasaki
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | saint anthony
# Processing Record 5 of Set 1 | springbok
# Processing Record 6 of Set 1 | belyy yar
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | lermontovka
# Processing Record 9 of Set 1 | berlevag
# Processing Record 10 of Set 1 | norman wells
# Processing Record 11 of Set 1 | fort nelson
# Processing Record 12 of Set 1 | guerrero negro
# Processing Record 13 of Set 1 | katherine
# Processing Record 14 of Set 1 | port lincoln
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | sitka
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | villamaria
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | lieksa
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | ca mau
# Processing Record 31 of Set 1 | leshukonskoye
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | bengkulu
# Processing Record 34 of Set 1 | muroto
# Processing Record 35 of Set 1 | hovd
# Processing Record 36 of Set 1 | sinnamary
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | ancud
# Processing Record 41 of Set 1 | san policarpo
# Processing Record 42 of Set 1 | talnakh
# Processing Record 43 of Set 1 | taitung
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | lithakia
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | arlit
# Processing Record 48 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 1 | shasta lake
# Processing Record 50 of Set 1 | trelew
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | garowe
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | ostrovnoy
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | mikkeli
# Processing Record 7 of Set 2 | russellville
# Processing Record 8 of Set 2 | inhambane
# Processing Record 9 of Set 2 | port hardy
# Processing Record 10 of Set 2 | haines junction
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | zaysan
# Processing Record 13 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 2 | uglegorsk
# Processing Record 15 of Set 2 | kavaratti
# Processing Record 16 of Set 2 | pangnirtung
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | nouakchott
# Processing Record 19 of Set 2 | hurghada
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | mahibadhoo
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | ostersund
# Processing Record 24 of Set 2 | margate
# Processing Record 25 of Set 2 | cachoeiras de macacu
# Processing Record 26 of Set 2 | wattegama
# Processing Record 27 of Set 2 | huancavelica
# Processing Record 28 of Set 2 | oktyabrskiy
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | tongzi
# Processing Record 33 of Set 2 | aklavik
# Processing Record 34 of Set 2 | ahipara
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | trat
# Processing Record 39 of Set 2 | wuwei
# Processing Record 40 of Set 2 | lamar
# Processing Record 41 of Set 2 | sloboda
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | araguaina
# Processing Record 45 of Set 2 | dwarka
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | kintampo
# Processing Record 49 of Set 2 | hami
# Processing Record 50 of Set 2 | mar del plata
# Processing Record 1 of Set 3 | te anau
# Processing Record 2 of Set 3 | mangrol
# Processing Record 3 of Set 3 | kandalaksha
# Processing Record 4 of Set 3 | payo
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | kieta
# Processing Record 7 of Set 3 | srednekolymsk
# Processing Record 8 of Set 3 | filingue
# Processing Record 9 of Set 3 | carnarvon
# Processing Record 10 of Set 3 | bonanza
# Processing Record 11 of Set 3 | karasburg
# Processing Record 12 of Set 3 | wanning
# Processing Record 13 of Set 3 | comodoro rivadavia
# Processing Record 14 of Set 3 | amanpur
# Processing Record 15 of Set 3 | mount gambier
# Processing Record 16 of Set 3 | lichinga
# Processing Record 17 of Set 3 | gat
# Processing Record 18 of Set 3 | moroto
# Processing Record 19 of Set 3 | henties bay
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | sorland
# Processing Record 22 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 3 | virginia beach
# Processing Record 24 of Set 3 | sandwick
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 3 | road town
# Processing Record 28 of Set 3 | leningradskiy
# Processing Record 29 of Set 3 | luderitz
# Processing Record 30 of Set 3 | san patricio
# Processing Record 31 of Set 3 | puerto ayora
# Processing Record 32 of Set 3 | sorong
# Processing Record 33 of Set 3 | namibe
# Processing Record 34 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 3 | bogovarovo
# Processing Record 36 of Set 3 | neiafu
# Processing Record 37 of Set 3 | naze
# Processing Record 38 of Set 3 | svetlogorsk
# Processing Record 39 of Set 3 | salalah
# Processing Record 40 of Set 3 | andevoranto
# City not found. Skipping...
# Processing Record 41 of Set 3 | bathsheba
# Processing Record 42 of Set 3 | jalu
# Processing Record 43 of Set 3 | riachao
# Processing Record 44 of Set 3 | marawi
# Processing Record 45 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 3 | kodiak
# Processing Record 47 of Set 3 | saldanha
# Processing Record 48 of Set 3 | yerofey pavlovich
# Processing Record 49 of Set 3 | lagoa
# Processing Record 50 of Set 3 | kibala
# Processing Record 1 of Set 4 | gueret
# Processing Record 2 of Set 4 | nome
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | kasaragod
# Processing Record 5 of Set 4 | melbu
# Processing Record 6 of Set 4 | port blair
# Processing Record 7 of Set 4 | bilma
# Processing Record 8 of Set 4 | san quintin
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | broken hill
# Processing Record 11 of Set 4 | miles city
# Processing Record 12 of Set 4 | banda aceh
# Processing Record 13 of Set 4 | ongandjera
# Processing Record 14 of Set 4 | atar
# Processing Record 15 of Set 4 | alihe
# Processing Record 16 of Set 4 | vershino-darasunskiy
# Processing Record 17 of Set 4 | pangai
# Processing Record 18 of Set 4 | shemonaikha
# Processing Record 19 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 4 | ketchikan
# Processing Record 21 of Set 4 | wad rawah
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 4 | bambous virieux
# Processing Record 25 of Set 4 | naryan-mar
# Processing Record 26 of Set 4 | rocha
# Processing Record 27 of Set 4 | pevek
# Processing Record 28 of Set 4 | batagay
# Processing Record 29 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 4 | fortuna
# Processing Record 31 of Set 4 | iqaluit
# Processing Record 32 of Set 4 | porto novo
# Processing Record 33 of Set 4 | akyab
# Processing Record 34 of Set 4 | along
# Processing Record 35 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | tarata
# Processing Record 37 of Set 4 | freeport
# Processing Record 38 of Set 4 | tambacounda
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | nizwa
# Processing Record 41 of Set 4 | severo-kurilsk
# Processing Record 42 of Set 4 | hobyo
# Processing Record 43 of Set 4 | noshiro
# Processing Record 44 of Set 4 | provideniya
# Processing Record 45 of Set 4 | pitimbu
# Processing Record 46 of Set 4 | hamilton
# Processing Record 47 of Set 4 | bata
# Processing Record 48 of Set 4 | hailar
# Processing Record 49 of Set 4 | kologriv
# Processing Record 50 of Set 4 | ibra
# Processing Record 1 of Set 5 | hithadhoo
# Processing Record 2 of Set 5 | codrington
# Processing Record 3 of Set 5 | hervey bay
# Processing Record 4 of Set 5 | hunfeld
# Processing Record 5 of Set 5 | ponta delgada
# Processing Record 6 of Set 5 | itarema
# Processing Record 7 of Set 5 | husavik
# Processing Record 8 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 9 of Set 5 | fairbanks
# Processing Record 10 of Set 5 | jinchang
# Processing Record 11 of Set 5 | upernavik
# Processing Record 12 of Set 5 | moron
# Processing Record 13 of Set 5 | nadym
# Processing Record 14 of Set 5 | thinadhoo
# Processing Record 15 of Set 5 | envira
# Processing Record 16 of Set 5 | kruisfontein
# Processing Record 17 of Set 5 | ban tak
# Processing Record 18 of Set 5 | yar-sale
# Processing Record 19 of Set 5 | andradas
# Processing Record 20 of Set 5 | beloha
# Processing Record 21 of Set 5 | lincoln
# Processing Record 22 of Set 5 | namatanai
# Processing Record 23 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 5 | launceston
# Processing Record 25 of Set 5 | agadez
# Processing Record 26 of Set 5 | vaini
# Processing Record 27 of Set 5 | cabo san lucas
# Processing Record 28 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 5 | shishou
# Processing Record 30 of Set 5 | manta
# Processing Record 31 of Set 5 | atambua
# Processing Record 32 of Set 5 | airai
# Processing Record 33 of Set 5 | teguise
# Processing Record 34 of Set 5 | jilib
# Processing Record 35 of Set 5 | narsaq
# Processing Record 36 of Set 5 | ballina
# Processing Record 37 of Set 5 | savannah bight
# Processing Record 38 of Set 5 | pringsewu
# Processing Record 39 of Set 5 | pizhanka
# Processing Record 40 of Set 5 | kutum
# Processing Record 41 of Set 5 | olafsvik
# Processing Record 42 of Set 5 | saint george
# Processing Record 43 of Set 5 | ust-nera
# Processing Record 44 of Set 5 | gamba
# Processing Record 45 of Set 5 | tigzirt
# Processing Record 46 of Set 5 | puntarenas
# Processing Record 47 of Set 5 | boryslav
# Processing Record 48 of Set 5 | olinda
# Processing Record 49 of Set 5 | faanui
# Processing Record 50 of Set 5 | sarangani
# Processing Record 1 of Set 6 | tarakan
# Processing Record 2 of Set 6 | kidal
# Processing Record 3 of Set 6 | pochutla
# Processing Record 4 of Set 6 | ust-uda
# Processing Record 5 of Set 6 | ilulissat
# Processing Record 6 of Set 6 | maun
# Processing Record 7 of Set 6 | lubango
# Processing Record 8 of Set 6 | vardo
# Processing Record 9 of Set 6 | morros
# Processing Record 10 of Set 6 | sol-iletsk
# Processing Record 11 of Set 6 | padang
# Processing Record 12 of Set 6 | hambantota
# Processing Record 13 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 14 of Set 6 | tromso
# Processing Record 15 of Set 6 | buin
# Processing Record 16 of Set 6 | knysna
# Processing Record 17 of Set 6 | ponta do sol
# Processing Record 18 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 6 | mahon
# Processing Record 20 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 6 | brae
# Processing Record 22 of Set 6 | yongan
# Processing Record 23 of Set 6 | raga
# Processing Record 24 of Set 6 | north bend
# Processing Record 25 of Set 6 | kuzino
# Processing Record 26 of Set 6 | cueto
# Processing Record 27 of Set 6 | riyadh
# Processing Record 28 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 29 of Set 6 | aksarka
# Processing Record 30 of Set 6 | wenchi
# Processing Record 31 of Set 6 | turukhansk
# Processing Record 32 of Set 6 | sur
# Processing Record 33 of Set 6 | mackay
# Processing Record 34 of Set 6 | maldonado
# Processing Record 35 of Set 6 | vilcun
# Processing Record 36 of Set 6 | makakilo city
# Processing Record 37 of Set 6 | ugoofaaru
# Processing Record 38 of Set 6 | conde
# Processing Record 39 of Set 6 | ola
# Processing Record 40 of Set 6 | manadhoo
# Processing Record 41 of Set 6 | aripuana
# Processing Record 42 of Set 6 | los llanos de aridane
# Processing Record 43 of Set 6 | kirakira
# Processing Record 44 of Set 6 | mwene-ditu
# Processing Record 45 of Set 6 | deyang
# Processing Record 46 of Set 6 | rockland
# Processing Record 47 of Set 6 | volsk
# Processing Record 48 of Set 6 | christchurch
# Processing Record 49 of Set 6 | palmerston
# Processing Record 50 of Set 6 | mirabad
# Processing Record 1 of Set 7 | clyde river
# Processing Record 2 of Set 7 | yatou
# Processing Record 3 of Set 7 | buraydah
# Processing Record 4 of Set 7 | rio cuarto
# Processing Record 5 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 7 | bereda
# Processing Record 7 of Set 7 | tiksi
# Processing Record 8 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 7 | yurgamysh
# Processing Record 10 of Set 7 | catuday
# Processing Record 11 of Set 7 | bitung
# Processing Record 12 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 7 | khatanga
# Processing Record 14 of Set 7 | lasa
# Processing Record 15 of Set 7 | vallenar
# Processing Record 16 of Set 7 | souillac
# Processing Record 17 of Set 7 | kahului
# Processing Record 18 of Set 7 | kaitangata
# Processing Record 19 of Set 7 | celestun
# Processing Record 20 of Set 7 | la ronge
# Processing Record 21 of Set 7 | batticaloa
# Processing Record 22 of Set 7 | tual
# Processing Record 23 of Set 7 | araras
# Processing Record 24 of Set 7 | nyimba
# Processing Record 25 of Set 7 | nouadhibou
# Processing Record 26 of Set 7 | cockburn town
# Processing Record 27 of Set 7 | deputatskiy
# Processing Record 28 of Set 7 | san andres
# Processing Record 29 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 7 | great yarmouth
# Processing Record 31 of Set 7 | glomfjord
# Processing Record 32 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 7 | birao
# Processing Record 34 of Set 7 | the valley
# Processing Record 35 of Set 7 | saint-denis
# Processing Record 36 of Set 7 | dawei
# Processing Record 37 of Set 7 | soyo
# Processing Record 38 of Set 7 | chuy
# Processing Record 39 of Set 7 | kolpashevo
# Processing Record 40 of Set 7 | kerema
# Processing Record 41 of Set 7 | yantal
# Processing Record 42 of Set 7 | inuvik
# Processing Record 43 of Set 7 | orlik
# Processing Record 44 of Set 7 | baruun-urt
# Processing Record 45 of Set 7 | bayan
# Processing Record 46 of Set 7 | bethel
# Processing Record 47 of Set 7 | phon
# Processing Record 48 of Set 7 | yelabuga
# Processing Record 49 of Set 7 | santa rosa
# Processing Record 50 of Set 7 | monticello
# Processing Record 1 of Set 8 | san jeronimo
# Processing Record 2 of Set 8 | sulina
# Processing Record 3 of Set 8 | vestmannaeyjar
# Processing Record 4 of Set 8 | santa vitoria do palmar
# Processing Record 5 of Set 8 | ierapetra
# Processing Record 6 of Set 8 | gidole
# Processing Record 7 of Set 8 | kapuskasing
# Processing Record 8 of Set 8 | flinders
# Processing Record 9 of Set 8 | hailey
# Processing Record 10 of Set 8 | mehamn
# Processing Record 11 of Set 8 | urucara
# Processing Record 12 of Set 8 | tuatapere
# Processing Record 13 of Set 8 | victor harbor
# Processing Record 14 of Set 8 | birobidzhan
# Processing Record 15 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 8 | annan
# Processing Record 17 of Set 8 | biskamzha
# Processing Record 18 of Set 8 | raudeberg
# Processing Record 19 of Set 8 | richards bay
# Processing Record 20 of Set 8 | eureka
# Processing Record 21 of Set 8 | esperance
# Processing Record 22 of Set 8 | blagoyevo
# Processing Record 23 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 24 of Set 8 | manono
# Processing Record 25 of Set 8 | joshimath
# Processing Record 26 of Set 8 | qaqortoq
# Processing Record 27 of Set 8 | erzincan
# Processing Record 28 of Set 8 | honningsvag
# Processing Record 29 of Set 8 | satipo
# Processing Record 30 of Set 8 | nelson bay
# Processing Record 31 of Set 8 | hastings
# Processing Record 32 of Set 8 | marystown
# Processing Record 33 of Set 8 | alta floresta
# Processing Record 34 of Set 8 | alofi
# Processing Record 35 of Set 8 | voka
# Processing Record 36 of Set 8 | susehri
# Processing Record 37 of Set 8 | port elizabeth
# Processing Record 38 of Set 8 | vila franca do campo
# Processing Record 39 of Set 8 | quatre cocos
# Processing Record 40 of Set 8 | verkhoyansk
# Processing Record 41 of Set 8 | lompoc
# Processing Record 42 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 43 of Set 8 | mocuba
# Processing Record 44 of Set 8 | doha
# Processing Record 45 of Set 8 | monrovia
# Processing Record 46 of Set 8 | nalut
# Processing Record 47 of Set 8 | voh
# Processing Record 48 of Set 8 | barcelos
# Processing Record 49 of Set 8 | kloulklubed
# Processing Record 50 of Set 8 | nikolskoye
# Processing Record 1 of Set 9 | shimoda
# Processing Record 2 of Set 9 | anadyr
# Processing Record 3 of Set 9 | arua
# Processing Record 4 of Set 9 | klaksvik
# Processing Record 5 of Set 9 | abu samrah
# Processing Record 6 of Set 9 | alexandria
# Processing Record 7 of Set 9 | beringovskiy
# Processing Record 8 of Set 9 | fukue
# Processing Record 9 of Set 9 | khandyga
# Processing Record 10 of Set 9 | torbay
# Processing Record 11 of Set 9 | camargo
# Processing Record 12 of Set 9 | olsztyn
# Processing Record 13 of Set 9 | beira
# Processing Record 14 of Set 9 | sligo
# Processing Record 15 of Set 9 | port-gentil
# Processing Record 16 of Set 9 | hofn
# Processing Record 17 of Set 9 | tura
# Processing Record 18 of Set 9 | canton
# Processing Record 19 of Set 9 | kenai
# Processing Record 20 of Set 9 | kokopo
# Processing Record 21 of Set 9 | porangatu
# Processing Record 22 of Set 9 | wajima
# Processing Record 23 of Set 9 | bubaque
# Processing Record 24 of Set 9 | malakal
# Processing Record 25 of Set 9 | nemuro
# Processing Record 26 of Set 9 | amuntai
# Processing Record 27 of Set 9 | geraldton
# Processing Record 28 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 9 | kenora
# Processing Record 30 of Set 9 | tazovskiy
# Processing Record 31 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 9 | tamworth
# Processing Record 34 of Set 9 | shingu
# Processing Record 35 of Set 9 | broome
# Processing Record 36 of Set 9 | les cayes
# Processing Record 37 of Set 9 | puerto carreno
# Processing Record 38 of Set 9 | hay river
# Processing Record 39 of Set 9 | buta
# Processing Record 40 of Set 9 | griffith
# Processing Record 41 of Set 9 | vuktyl
# Processing Record 42 of Set 9 | zalantun
# Processing Record 43 of Set 9 | nizhnetroitskiy
# Processing Record 44 of Set 9 | isla mujeres
# Processing Record 45 of Set 9 | tallahassee
# Processing Record 46 of Set 9 | buala
# Processing Record 47 of Set 9 | ciudad bolivar
# Processing Record 48 of Set 9 | ust-omchug
# Processing Record 49 of Set 9 | mayo
# Processing Record 50 of Set 9 | westport
# Processing Record 1 of Set 10 | georgetown
# Processing Record 2 of Set 10 | kedougou
# Processing Record 3 of Set 10 | brindisi
# Processing Record 4 of Set 10 | lakshmeshwar
# Processing Record 5 of Set 10 | suba
# Processing Record 6 of Set 10 | half moon bay
# Processing Record 7 of Set 10 | katangli
# Processing Record 8 of Set 10 | tshikapa
# Processing Record 9 of Set 10 | qasigiannguit
# Processing Record 10 of Set 10 | rantauprapat
# Processing Record 11 of Set 10 | waw
# Processing Record 12 of Set 10 | afua
# Processing Record 13 of Set 10 | brazzaville
# Processing Record 14 of Set 10 | trapani
# Processing Record 15 of Set 10 | kankakee
# Processing Record 16 of Set 10 | veraval
# Processing Record 17 of Set 10 | jacareacanga
# Processing Record 18 of Set 10 | grand gaube
# Processing Record 19 of Set 10 | basar
# Processing Record 20 of Set 10 | havre-saint-pierre
# Processing Record 21 of Set 10 | alzamay
# Processing Record 22 of Set 10 | isangel
# Processing Record 23 of Set 10 | evensk
# Processing Record 24 of Set 10 | ishigaki
# Processing Record 25 of Set 10 | antofagasta
# Processing Record 26 of Set 10 | samarai
# Processing Record 27 of Set 10 | gulu
# Processing Record 28 of Set 10 | solnechnyy
# Processing Record 29 of Set 10 | rudsar
# Processing Record 30 of Set 10 | palmer
# Processing Record 31 of Set 10 | faya
# Processing Record 32 of Set 10 | xanlar
# Processing Record 33 of Set 10 | channelview
# Processing Record 34 of Set 10 | batemans bay
# Processing Record 35 of Set 10 | nova olinda do norte
# Processing Record 36 of Set 10 | salamiyah
# Processing Record 37 of Set 10 | ambilobe
# Processing Record 38 of Set 10 | kabanjahe
# Processing Record 39 of Set 10 | rio grande
# Processing Record 40 of Set 10 | tara
# Processing Record 41 of Set 10 | waitati
# Processing Record 42 of Set 10 | alugan
# Processing Record 43 of Set 10 | inta
# Processing Record 44 of Set 10 | yulara
# Processing Record 45 of Set 10 | poum
# Processing Record 46 of Set 10 | denison
# Processing Record 47 of Set 10 | warwick
# Processing Record 48 of Set 10 | camana
# Processing Record 49 of Set 10 | allapalli
# Processing Record 50 of Set 10 | kvelde
# City not found. Skipping...
# Processing Record 1 of Set 11 | salina cruz
# Processing Record 2 of Set 11 | romny
# Processing Record 3 of Set 11 | manokwari
# Processing Record 4 of Set 11 | asau
# Processing Record 5 of Set 11 | chapais
# Processing Record 6 of Set 11 | la ciotat
# Processing Record 7 of Set 11 | siniscola
# Processing Record 8 of Set 11 | pushkino
# Processing Record 9 of Set 11 | itoman
# Processing Record 10 of Set 11 | caravelas
# Processing Record 11 of Set 11 | okhotsk
# Processing Record 12 of Set 11 | pisco
# Processing Record 13 of Set 11 | chimoio
# Processing Record 14 of Set 11 | flin flon
# Processing Record 15 of Set 11 | shetpe
# Processing Record 16 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 18 of Set 11 | nyaunglebin
# Processing Record 19 of Set 11 | guaruja
# Processing Record 20 of Set 11 | cidreira
# Processing Record 21 of Set 11 | kindu
# Processing Record 22 of Set 11 | lata
# Processing Record 23 of Set 11 | cazones
# Processing Record 24 of Set 11 | wasilla
# Processing Record 25 of Set 11 | kastamonu
# Processing Record 26 of Set 11 | sao joao da barra
# Processing Record 27 of Set 11 | port macquarie
# Processing Record 28 of Set 11 | cabo rojo
# Processing Record 29 of Set 11 | strathmore
# Processing Record 30 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 31 of Set 11 | carballo
# Processing Record 32 of Set 11 | kautokeino
# Processing Record 33 of Set 11 | harper
# Processing Record 34 of Set 11 | joaquim gomes
# Processing Record 35 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 11 | afogados da ingazeira
# Processing Record 37 of Set 11 | wana
# Processing Record 38 of Set 11 | west fargo
# Processing Record 39 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 11 | maridi
# Processing Record 41 of Set 11 | arcata
# Processing Record 42 of Set 11 | vidim
# Processing Record 43 of Set 11 | bridgton
# Processing Record 44 of Set 11 | strezhevoy
# Processing Record 45 of Set 11 | prado
# Processing Record 46 of Set 11 | cayenne
# Processing Record 47 of Set 11 | pottsville
# Processing Record 48 of Set 11 | mecca
# Processing Record 49 of Set 11 | louisville
# Processing Record 50 of Set 11 | saint helens
# Processing Record 1 of Set 12 | we
# City not found. Skipping...
# Processing Record 2 of Set 12 | churapcha
# Processing Record 3 of Set 12 | tiarei
# Processing Record 4 of Set 12 | marsabit
# Processing Record 5 of Set 12 | honiara
# Processing Record 6 of Set 12 | yeppoon
# Processing Record 7 of Set 12 | shieli
# Processing Record 8 of Set 12 | samarinda
# Processing Record 9 of Set 12 | kemijarvi
# Processing Record 10 of Set 12 | samarkand
# Processing Record 11 of Set 12 | winnemucca
# Processing Record 12 of Set 12 | kawalu
# Processing Record 13 of Set 12 | sabancuy
# Processing Record 14 of Set 12 | cherskiy
# Processing Record 15 of Set 12 | sogdiondon
# City not found. Skipping...
# Processing Record 16 of Set 12 | chuncheng
# Processing Record 17 of Set 12 | dzhebariki-khaya
# Processing Record 18 of Set 12 | providencia
# Processing Record 19 of Set 12 | lavrentiya
# Processing Record 20 of Set 12 | aktau
# Processing Record 21 of Set 12 | beisfjord
# Processing Record 22 of Set 12 | horta
# Processing Record 23 of Set 12 | limoux
# Processing Record 24 of Set 12 | katobu
# Processing Record 25 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 26 of Set 12 | vanimo
# Processing Record 27 of Set 12 | lhokseumawe
# Processing Record 28 of Set 12 | urumqi
# Processing Record 29 of Set 12 | tuy hoa
# Processing Record 30 of Set 12 | ilhabela
# Processing Record 31 of Set 12 | marsaxlokk
# Processing Record 32 of Set 12 | lebu
# Processing Record 33 of Set 12 | katghora
# Processing Record 34 of Set 12 | bilokurakyne
# Processing Record 35 of Set 12 | green valley
# Processing Record 36 of Set 12 | wolverhampton
# Processing Record 37 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 38 of Set 12 | point fortin
# Processing Record 39 of Set 12 | palmital
# Processing Record 40 of Set 12 | poronaysk
# Processing Record 41 of Set 12 | yanam
# Processing Record 42 of Set 12 | pundaguitan
# Processing Record 43 of Set 12 | najran
# Processing Record 44 of Set 12 | chernigovka
# Processing Record 45 of Set 12 | noumea
# Processing Record 46 of Set 12 | sovetskiy
# Processing Record 47 of Set 12 | lesnoy
# Processing Record 48 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 12 | komsomolskiy
# Processing Record 50 of Set 12 | namtsy
# Processing Record 1 of Set 13 | pericos
# Processing Record 2 of Set 13 | ganta
# Processing Record 3 of Set 13 | huilong
# Processing Record 4 of Set 13 | roma
# Processing Record 5 of Set 13 | pervomayskoye
# Processing Record 6 of Set 13 | college
# Processing Record 7 of Set 13 | tarko-sale
# Processing Record 8 of Set 13 | stornoway
# Processing Record 9 of Set 13 | kaoma
# Processing Record 10 of Set 13 | lianzhou
# Processing Record 11 of Set 13 | sala
# Processing Record 12 of Set 13 | fuyang
# Processing Record 13 of Set 13 | gao
# Processing Record 14 of Set 13 | nsanje
# Processing Record 15 of Set 13 | yizheng
# Processing Record 16 of Set 13 | zhuanghe
# Processing Record 17 of Set 13 | lodhran
# Processing Record 18 of Set 13 | megion
# Processing Record 19 of Set 13 | mezen
# Processing Record 20 of Set 13 | den helder
# Processing Record 21 of Set 13 | dunedin
# Processing Record 22 of Set 13 | mandvi
# Processing Record 23 of Set 13 | ilmajoki
# Processing Record 24 of Set 13 | meulaboh
# Processing Record 25 of Set 13 | san cristobal
# Processing Record 26 of Set 13 | biltine
# Processing Record 27 of Set 13 | tondano
# Processing Record 28 of Set 13 | ukiah
# Processing Record 29 of Set 13 | coos bay
# Processing Record 30 of Set 13 | khasan
# Processing Record 31 of Set 13 | kongsberg
# Processing Record 32 of Set 13 | sept-iles
# Processing Record 33 of Set 13 | chara
# Processing Record 34 of Set 13 | podor
# Processing Record 35 of Set 13 | dingle
# Processing Record 36 of Set 13 | madimba
# Processing Record 37 of Set 13 | hokitika
# Processing Record 38 of Set 13 | talaya
# Processing Record 39 of Set 13 | jiuquan
# Processing Record 40 of Set 13 | constitucion
# Processing Record 41 of Set 13 | sakaiminato
# Processing Record 42 of Set 13 | marienburg
# Processing Record 43 of Set 13 | ocampo
# Processing Record 44 of Set 13 | jeremie
# Processing Record 45 of Set 13 | oussouye
# Processing Record 46 of Set 13 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 47 of Set 13 | grakhovo
# Processing Record 48 of Set 13 | miramar
# Processing Record 49 of Set 13 | zhigansk
# Processing Record 50 of Set 13 | cravo norte
# Processing Record 1 of Set 14 | aldan
# Processing Record 2 of Set 14 | garissa
# Processing Record 3 of Set 14 | adrar
# Processing Record 4 of Set 14 | tilichiki
# Processing Record 5 of Set 14 | jamame
# Processing Record 6 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 14 | mishan
# Processing Record 8 of Set 14 | dekar
# Processing Record 9 of Set 14 | bekwai
# Processing Record 10 of Set 14 | yumen
# Processing Record 11 of Set 14 | chunhuhub
# Processing Record 12 of Set 14 | paamiut
# Processing Record 13 of Set 14 | gacko
# Processing Record 14 of Set 14 | tahoua
# Processing Record 15 of Set 14 | nigran
# Processing Record 16 of Set 14 | chegdomyn
# Processing Record 17 of Set 14 | severo-yeniseyskiy
# Processing Record 18 of Set 14 | sampit
# Processing Record 19 of Set 14 | saint-pierre
# Processing Record 20 of Set 14 | skelleftea
# Processing Record 21 of Set 14 | bandarbeyla
# Processing Record 22 of Set 14 | qurayyat
# Processing Record 23 of Set 14 | novyy urengoy
# Processing Record 24 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 14 | burnie
# Processing Record 27 of Set 14 | fare
# Processing Record 28 of Set 14 | necochea
# Processing Record 29 of Set 14 | matara
# Processing Record 30 of Set 14 | avera
# Processing Record 31 of Set 14 | aswan
# Processing Record 32 of Set 14 | canatlan
# Processing Record 33 of Set 14 | iwanai
# Processing Record 34 of Set 14 | brooks
# Processing Record 35 of Set 14 | asfi
# Processing Record 36 of Set 14 | teresopolis
# Processing Record 37 of Set 14 | marfino
# Processing Record 38 of Set 14 | lerik
# Processing Record 39 of Set 14 | wladyslawowo
# Processing Record 40 of Set 14 | concepcion
# Processing Record 41 of Set 14 | homburg
# Processing Record 42 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 43 of Set 14 | talcahuano
# Processing Record 44 of Set 14 | portland
# Processing Record 45 of Set 14 | vilhena
# Processing Record 46 of Set 14 | middleton
# Processing Record 47 of Set 14 | stanghelle
# Processing Record 48 of Set 14 | san jose
# Processing Record 49 of Set 14 | tornio
# Processing Record 50 of Set 14 | lugovoy
# Processing Record 1 of Set 15 | marilia
# Processing Record 2 of Set 15 | walvis bay
# Processing Record 3 of Set 15 | tukrah
# Processing Record 4 of Set 15 | vostok
# Processing Record 5 of Set 15 | vega de alatorre
# Processing Record 6 of Set 15 | laguna
# Processing Record 7 of Set 15 | hollabrunn
# Processing Record 8 of Set 15 | chernyshevskiy
# Processing Record 9 of Set 15 | ewa beach
# Processing Record 10 of Set 15 | tocopilla
# Processing Record 11 of Set 15 | ambositra
# Processing Record 12 of Set 15 | at-bashi
# Processing Record 13 of Set 15 | mbekenyera
# Processing Record 14 of Set 15 | ozubulu
# Processing Record 15 of Set 15 | sembe
# Processing Record 16 of Set 15 | terrace
# Processing Record 17 of Set 15 | carutapera
# Processing Record 18 of Set 15 | goderich
# Processing Record 19 of Set 15 | shelburne
# Processing Record 20 of Set 15 | karratha
# Processing Record 21 of Set 15 | altar
# Processing Record 22 of Set 15 | mushie
# Processing Record 23 of Set 15 | boende
# Processing Record 24 of Set 15 | chiredzi
# Processing Record 25 of Set 15 | cosala
# Processing Record 26 of Set 15 | el estor
# Processing Record 27 of Set 15 | zhireken
# Processing Record 28 of Set 15 | seminole
# Processing Record 29 of Set 15 | muravlenko
# Processing Record 30 of Set 15 | kuche
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 679

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hasaki  35.7333  140.8333     75.60        82          87
# 1      Busselton -33.6500  115.3333     55.81        73          93
# 2        Rikitea -23.1203 -134.9692     69.71        64          68
# 3  Saint Anthony  45.0205  -93.2180     75.92        44         100
# 4      Springbok -29.6643   17.8865     49.50        57           0
# 5      Belyy Yar  53.6039   91.3903     26.49        86           0
# 6           Hilo  19.7297 -155.0900     91.27        64          20
# 7    Lermontovka  47.1453  134.3383     30.61        65           0
# 8       Berlevåg  70.8578   29.0864     42.75        75         100
# 9   Norman Wells  65.2820 -126.8329     39.99        74          88
#
#    Wind Speed Country Current Description
# 0       19.06      JP     overcast clouds
# 1       13.38      AU     overcast clouds
# 2       24.27      PF       broken clouds
# 3        9.22      US     overcast clouds
# 4        1.61      ZA           clear sky
# 5        4.47      RU           clear sky
# 6       11.50      US          few clouds
# 7        4.74      RU           clear sky
# 8        9.22      NO     overcast clouds
# 9       11.68      CA     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hasaki      JP  35.7333  140.8333     75.60        82          87
# 1      Busselton      AU -33.6500  115.3333     55.81        73          93
# 2        Rikitea      PF -23.1203 -134.9692     69.71        64          68
# 3  Saint Anthony      US  45.0205  -93.2180     75.92        44         100
# 4      Springbok      ZA -29.6643   17.8865     49.50        57           0
# 5      Belyy Yar      RU  53.6039   91.3903     26.49        86           0
# 6           Hilo      US  19.7297 -155.0900     91.27        64          20
# 7    Lermontovka      RU  47.1453  134.3383     30.61        65           0
# 8       Berlevåg      NO  70.8578   29.0864     42.75        75         100
# 9   Norman Wells      CA  65.2820 -126.8329     39.99        74          88
#
#    Wind Speed Current Description
# 0       19.06     overcast clouds
# 1       13.38     overcast clouds
# 2       24.27       broken clouds
# 3        9.22     overcast clouds
# 4        1.61           clear sky
# 5        4.47           clear sky
# 6       11.50          few clouds
# 7        4.74           clear sky
# 8        9.22     overcast clouds
# 9       11.68     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(file)
